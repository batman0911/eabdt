# %%
import pandas as pd
import numpy as np

# %%
num_batch = 372

# %%
confuse = []
for i in range(num_batch):
  X = np.load(f'../data/vectorize/All_Beauty/X_{i}.npy')
  X = pd.DataFrame(X)
  # X = pd.read_csv(f'../data/raw/All_Beauty/X_{i}.csv')
  y = pd.read_csv(f'../data/raw/All_Beauty/y_{i}.csv')
  
  sx = X.shape[0]
  sy = y.shape[0]
  
  if sx != sy:
    confuse.append({
        'batch': i,
        'sx': sx,
        'sy': sy
      })
  print(f'batch: {i}, sx: {sx}, sy: {sy}')
    
print(confuse)
# Out:
# batch: 0, sx: 999, sy: 999
# batch: 1, sx: 1000, sy: 1000
# batch: 2, sx: 1000, sy: 1000
# batch: 3, sx: 999, sy: 999
# batch: 4, sx: 999, sy: 999
# batch: 5, sx: 1000, sy: 1000
# batch: 6, sx: 997, sy: 997
# batch: 7, sx: 1000, sy: 1000
# batch: 8, sx: 1000, sy: 1000
# batch: 9, sx: 1000, sy: 1000
# batch: 10, sx: 999, sy: 999
# batch: 11, sx: 1000, sy: 1000
# batch: 12, sx: 1000, sy: 1000
# batch: 13, sx: 1000, sy: 1000
# batch: 14, sx: 999, sy: 999
# batch: 15, sx: 1000, sy: 1000
# batch: 16, sx: 999, sy: 999
# batch: 17, sx: 1000, sy: 1000
# batch: 18, sx: 1000, sy: 1000
# batch: 19, sx: 999, sy: 999
# batch: 20, sx: 999, sy: 999
# batch: 21, sx: 1000, sy: 1000
# batch: 22, sx: 999, sy: 999
# batch: 23, sx: 1000, sy: 1000
# batch: 24, sx: 1000, sy: 1000
# batch: 25, sx: 999, sy: 999
# batch: 26, sx: 1000, sy: 1000
# batch: 27, sx: 999, sy: 999
# batch: 28, sx: 1000, sy: 1000
# batch: 29, sx: 1000, sy: 1000
# batch: 30, sx: 999, sy: 999
# batch: 31, sx: 1000, sy: 1000
# ...

# %%
print(len(confuse))
# Out:
# 0

# %%
X0 = pd.read_csv('../data/raw/All_Beauty/X_0.csv')
y0 = pd.read_csv('../data/raw/All_Beauty/y_0.csv')

# %%
print(X0.shape, y0.shape)
# Out:
# (999, 1) (999, 1)

# %%
# for i in range(2):
#   Xnp = np.load(f'../data/vectorize/All_Beauty/X_{i}.npy')
#   y = pd.read_csv(f'../data/raw/All_Beauty/y_{i}.csv')
  
#   print(f'X shape: {Xnp.shape}, y shape: {y.shape}')
